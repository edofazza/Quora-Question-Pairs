# %% [markdown]
# # LSTM basic

# %% [markdown]
# # Import libraries

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import scipy
import os
import string
import csv
import random as rn

import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import warnings
warnings.filterwarnings('ignore')

from sklearn import preprocessing
import spacy
import matplotlib.pyplot as plt
import plotly.graph_objects as go

import re
from string import punctuation
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

from keras.preprocessing.text import Tokenizer
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split

from keras.models import Sequential, Model
from keras.layers import Input, Embedding, Dense, Dropout, LSTM

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import optimizers
import shutil
from sklearn import metrics
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow.keras import layers
from sklearn.utils import class_weight
from keras import backend as K

from attention import Attention

# %%
pip install attention

# %% [markdown]
# # Load dataset

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cp --verbose -R "/content/drive/MyDrive/Quora/Dataset" "/content"

# %% [markdown]
# # Set Parameters

# %%
DATASET_PATH = '/content/Dataset'

LOCAL_MODELS_FOLDER = "/content/Models"
if not os.path.exists(LOCAL_MODELS_FOLDER):
  os.makedirs(LOCAL_MODELS_FOLDER)
GLOBAL_MODELS_FOLDER = "/content/drive/My Drive/Quora/Models/LSTM"

HISTORIES_FOLDER = "/content/drive/My Drive/Quora/Histories/LSTM"

BATCH_SIZE = 64
SEED = 24

# %% [markdown]
# # Utility Functions

# %%
def set_seed ():
  ''' 
  set_seed is used to obtain reproducible results using keras during the development phase
  '''
  # The below is necessary for reproducible results of certain Python hash-based operations.
  os.environ["PYTHONHASHSEED"]="0"
  # The below is necessary for starting Numpy generated random numbers in a well-defined initial state.
  np.random.seed(SEED)
  # The below is necessary for starting core Python generated random numbers in a well-defined state.
  rn.seed(SEED)
  # The below tf.random.set_seed will make random number generation in TensorFlow have a well-defined initial state.
  tf.random.set_seed(SEED)

def show_training_and_validation_performance(history):
  '''
  show_training_and_validation_performance is used to plot the performances during the training phase
  :param history: object in which are recorded all the events
  '''
  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'bo', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'bo', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

def compile_model (model, optimizer='adam', learning_rate = 0.001):
  '''
  compile_model is used to compile the current model
  :param model: model to compile
  :param optimizer: optimizer to be used
  :param learning_rate: learning rate parameter for the optimizer
  '''
  if optimizer == 'adam':
    model.compile(loss="binary_crossentropy",
      optimizer=optimizers.Adam(learning_rate=learning_rate),
      metrics=["accuracy"])
  elif optimizer == 'rmsprop':
    model.compile(loss="binary_crossentropy",
                  optimizer = optimizers.RMSprop(learning_rate=learning_rate),
                  metrics=['accuracy'])
  model.summary()

def run_model (model, model_name, X_train, y_train, X_validation, y_validation, epochs = 50, patience = 5, monitor='val_loss', class_weight=None):
  '''
  run_model is used to run the current mode
  :param model: model to run
  :param model_name: name given to save the model
  :param epochs: how many epochs to do
  :param patience: patience value for Early Stopping
  :param monitor: what to monitor for Early Stopping and Model Checkpoint
  '''
  # local save path for the models
  save_path = LOCAL_MODELS_FOLDER + '/' + model_name + '.h5'
  callbacks_list = [
                  keras.callbacks.EarlyStopping(monitor=monitor, patience=patience),
                  keras.callbacks.ModelCheckpoint(
                      filepath = save_path,
                      monitor=monitor,
                      verbose=1,
                      save_best_only=True)
                  ]
  history = model.fit(X_train, y_train,
                    epochs=epochs,
                    batch_size=BATCH_SIZE,
                    validation_data=(X_validation, y_validation),
                    callbacks=callbacks_list,
                    class_weight=class_weight)
  # save on Drive only the best model
  shutil.copy(save_path, GLOBAL_MODELS_FOLDER + '/' + model_name + '.h5')

  # save on Drive also the history object
  history_df = pd.DataFrame(history.history)
  with open(HISTORIES_FOLDER + '/' + model_name + '.csv', mode='w+') as f:
    history_df.to_csv(f)

  show_training_and_validation_performance(history)

def evaluate_model (model, X_test, y_test):
  '''
  evaluate_model is used to plot some statistics about the performance on the test set
  :param model: model to consider
  '''
  y_score = model.predict(X_test)
  y_pred = np.rint(y_score) # to have 0 or 1
  y_true = y_test
  print("Classification report: ")
  print(metrics.classification_report(y_true,y_pred,digits = 4))
  metrics.ConfusionMatrixDisplay.from_predictions(y_true, y_pred)

  # ROC curve
  fpr,tpr,th = metrics.roc_curve(y_true,y_score)
  roc_auc = metrics.roc_auc_score(y_true,y_score)

  plt.figure()
  plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.0])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC curve')
  plt.legend(loc="lower right")
  plt.show()

def txt_process(input_text):
  '''
  txt_process is used to preprocess a question
  :param input_text: input string
  :return: the cleaned version of the input string
  '''
  # Removing punctuation from input text
  input_text = ''.join([x for x in input_text if x not in punctuation])
  # Cleaning the text
  input_text = re.sub(r"[^A-Za-z0-9]", " ", input_text)
  input_text = re.sub(r"\'s", " ", input_text)
  # remove stop words
  input_text = input_text.split()
  input_text = [x for x in input_text if not x in stop_words]
  input_text = " ".join(input_text)
  # return a list of words
  return(input_text)

# %% [markdown]
# # Preprocessing data

# %%
train_questions = pd.read_csv(DATASET_PATH + '/training.csv')
validation_questions = pd.read_csv(DATASET_PATH + '/validation.csv')
test_questions = pd.read_csv(DATASET_PATH + '/test.csv')

# %%
train_questions
# Out:
#             id    qid1    qid2  \
# 0       216036  322068  322069
# 1       241554  353581  353582
# 2       208738  312815  312816
# 3       102714  104282   77231
# 4       397304  178955   34172
# ...        ...     ...     ...
# 323426  189944    8395   34814
# 323427  330730  110579  457526
# 323428  143114  226824  175127
# 323429   10918   21121   21122
# 323430   57378  100834  100835
#
#                                                 question1  \
# 0       How can I sell at Snapdeal? What are the terms...
# 1       Why are most prosecutors in American courts no...
# 2       What are some good government jobs without a c...
# 3       What would happen if humans no longer needed t...
# 4                          How do I shave my bikini line?
# ...                                                   ...
# 323426            Is it true that the US is funding ISIS?
# 323427            How do I play in share market in India?
# 323428  What is the difference between laundry deterge...
# 323429  Would you consider teaching as a full time job...
# 323430  What drugs are readily accessible in Canada ov...
#
#                                                 question2  is_duplicate
# 0       What are the payment terms for online marketpl...             0
# 1       Why does a country like USA where law enforcem...             0
# 2       Are there any good companies that hire smart p...             0
# 3       What would the world be like if humans didn't ...             1
# 4          What is the best way to shave the bikini area?             1
# ...                                                   ...           ...
# 323426         Is it really true that US is backing ISIS?             1
# 323427  How can I study and invest in the Indian share...             0
# 323428  How safe is it to use non-HE detergent in a HE...             0
# 323429    Would you consider teaching as a full time job?             1
# 323430  What legal drugs (i.e. bought 'over the counte...             0
#
# [323431 rows x 6 columns]

# %%
train_questions['question1_cleaned'] = train_questions.apply(lambda x: txt_process(x['question1']), axis = 1)
train_questions['question2_cleaned'] = train_questions.apply(lambda x: txt_process(x['question2']), axis = 1)

validation_questions['question1_cleaned'] = validation_questions.apply(lambda x: txt_process(x['question1']), axis = 1)
validation_questions['question2_cleaned'] = validation_questions.apply(lambda x: txt_process(x['question2']), axis = 1)

test_questions['question1_cleaned'] = test_questions.apply(lambda x: txt_process(x['question1']), axis = 1)
test_questions['question2_cleaned'] = test_questions.apply(lambda x: txt_process(x['question2']), axis = 1)

# %%
train_questions
# Out:
#             id    qid1    qid2  \
# 0       216036  322068  322069
# 1       241554  353581  353582
# 2       208738  312815  312816
# 3       102714  104282   77231
# 4       397304  178955   34172
# ...        ...     ...     ...
# 323426  189944    8395   34814
# 323427  330730  110579  457526
# 323428  143114  226824  175127
# 323429   10918   21121   21122
# 323430   57378  100834  100835
#
#                                                 question1  \
# 0       How can I sell at Snapdeal? What are the terms...
# 1       Why are most prosecutors in American courts no...
# 2       What are some good government jobs without a c...
# 3       What would happen if humans no longer needed t...
# 4                          How do I shave my bikini line?
# ...                                                   ...
# 323426            Is it true that the US is funding ISIS?
# 323427            How do I play in share market in India?
# 323428  What is the difference between laundry deterge...
# 323429  Would you consider teaching as a full time job...
# 323430  What drugs are readily accessible in Canada ov...
#
#                                                 question2  is_duplicate  \
# 0       What are the payment terms for online marketpl...             0
# 1       Why does a country like USA where law enforcem...             0
# 2       Are there any good companies that hire smart p...             0
# 3       What would the world be like if humans didn't ...             1
# 4          What is the best way to shave the bikini area?             1
# ...                                                   ...           ...
# 323426         Is it really true that US is backing ISIS?             1
# 323427  How can I study and invest in the Indian share...             0
# 323428  How safe is it to use non-HE detergent in a HE...             0
# 323429    Would you consider teaching as a full time job?             1
# 323430  What legal drugs (i.e. bought 'over the counte...             0
#
#                                         question1_cleaned  \
# 0               How I sell Snapdeal What terms conditions
# 1       Why prosecutors American courts notoriously di...
# 2        What good government jobs without college degree
# 3            What would happen humans longer needed sleep
# 4                                 How I shave bikini line
# ...                                                   ...
# 323426                            Is true US funding ISIS
# 323427                      How I play share market India
# 323428  What difference laundry detergent bleach laund...
# 323429          Would consider teaching full time job Why
# 323430  What drugs readily accessible Canada counter r...
#
#                                         question2_cleaned
# 0       What payment terms online marketplaces like Fl...
# 1       Why country like USA law enforcements strict l...
# 2       Are good companies hire smart people without c...
# 3           What would world like humans didnt need sleep
# 4                         What best way shave bikini area
# ...                                                   ...
# 323426                     Is really true US backing ISIS
# 323427             How I study invest Indian share market
# 323428     How safe use nonHE detergent HE laundry washer
# 323429              Would consider teaching full time job
# 323430  What legal drugs ie bought counter cause loss ...
#
# [323431 rows x 8 columns]

# %% [markdown]
# # Use Tokenization

# %% [markdown]
# # Text to Feature
# Let’s stack both question IDs together so we can cover all words from both columns. Then we can tokenize these words to convert them to numbers. Some questions are very long, we considered only the first 25 words for each question.

# %%
#stacking
question_text = np.hstack([train_questions.question1_cleaned, train_questions.question2_cleaned])

#tokenizing
tokenizer = Tokenizer(oov_token='<OOV>')
tokenizer.fit_on_texts(question_text)

# define the max length of the single tokenizer
max_len_tokenizers = 25

#creating new columns for both ids where tokenized form of sentence is created
train_questions['tokenizer_1'] = tokenizer.texts_to_sequences(train_questions.question1_cleaned)
train_questions['tokenizer_1'] = sequence.pad_sequences(train_questions.tokenizer_1, maxlen = max_len_tokenizers, padding='post', truncating='post').tolist()
train_questions['tokenizer_2'] = tokenizer.texts_to_sequences(train_questions.question2_cleaned)
train_questions['tokenizer_2'] = sequence.pad_sequences(train_questions.tokenizer_2, maxlen = max_len_tokenizers, padding='post', truncating='post').tolist()

validation_questions['tokenizer_1'] = tokenizer.texts_to_sequences(validation_questions.question1_cleaned)
validation_questions['tokenizer_1'] = sequence.pad_sequences(validation_questions.tokenizer_1, maxlen = max_len_tokenizers, padding='post', truncating='post').tolist()
validation_questions['tokenizer_2'] = tokenizer.texts_to_sequences(validation_questions.question2_cleaned)
validation_questions['tokenizer_2'] = sequence.pad_sequences(validation_questions.tokenizer_2, maxlen = max_len_tokenizers, padding='post', truncating='post').tolist()

test_questions['tokenizer_1'] = tokenizer.texts_to_sequences(test_questions.question1_cleaned)
test_questions['tokenizer_1'] = sequence.pad_sequences(test_questions.tokenizer_1, maxlen = max_len_tokenizers, padding='post', truncating='post').tolist()
test_questions['tokenizer_2'] = tokenizer.texts_to_sequences(test_questions.question2_cleaned)
test_questions['tokenizer_2'] = sequence.pad_sequences(test_questions.tokenizer_2, maxlen = max_len_tokenizers, padding='post', truncating='post').tolist()

train_questions.head(5)
# Out:
#        id    qid1    qid2                                          question1  \
# 0  216036  322068  322069  How can I sell at Snapdeal? What are the terms...
# 1  241554  353581  353582  Why are most prosecutors in American courts no...
# 2  208738  312815  312816  What are some good government jobs without a c...
# 3  102714  104282   77231  What would happen if humans no longer needed t...
# 4  397304  178955   34172                     How do I shave my bikini line?
#
#                                            question2  is_duplicate  \
# 0  What are the payment terms for online marketpl...             0
# 1  Why does a country like USA where law enforcem...             0
# 2  Are there any good companies that hire smart p...             0
# 3  What would the world be like if humans didn't ...             1
# 4     What is the best way to shave the bikini area?             1
#
#                                    question1_cleaned  \
# 0          How I sell Snapdeal What terms conditions
# 1  Why prosecutors American courts notoriously di...
# 2   What good government jobs without college degree
# 3       What would happen humans longer needed sleep
# 4                            How I shave bikini line
#
#                                    question2_cleaned  \
# 0  What payment terms online marketplaces like Fl...
# 1  Why country like USA law enforcements strict l...
# 2  Are good companies hire smart people without c...
# 3      What would world like humans didnt need sleep
# 4                    What best way shave bikini area
#
#                                          tokenizer_1  \
# 0  [4, 3, 522, 4905, 2, 466, 3146, 0, 0, 0, 0, 0,...
# 1  [5, 28363, 292, 4730, 32476, 12231, 1100, 145,...
# 2  [2, 14, 164, 334, 44, 125, 418, 0, 0, 0, 0, 0,...
# 3  [2, 15, 119, 475, 1192, 1143, 412, 0, 0, 0, 0,...
# 4  [4, 3, 3379, 6390, 702, 0, 0, 0, 0, 0, 0, 0, 0...
#
#                                          tokenizer_2
# 0  [2, 1603, 466, 47, 14382, 13, 2223, 7716, 4905...
# 1  [5, 135, 13, 208, 404, 75956, 6164, 2008, 1221...
# 2  [42, 14, 181, 797, 770, 11, 44, 125, 418, 0, 0...
# 3  [2, 15, 50, 13, 475, 490, 92, 412, 0, 0, 0, 0,...
# 4  [2, 6, 18, 3379, 6390, 619, 0, 0, 0, 0, 0, 0, ...

# %%
num_distinct_words = len(tokenizer.word_index)
num_distinct_words
# Out:
# 96689

# %% [markdown]
# Combining both tokens of question1 and question2

# %%
train_questions['tokenizer'] = train_questions['tokenizer_1'] + train_questions['tokenizer_2']
validation_questions['tokenizer'] = validation_questions['tokenizer_1'] + validation_questions['tokenizer_2']
test_questions['tokenizer'] = test_questions['tokenizer_1'] + test_questions['tokenizer_2']

# defining total max length
m_len = max_len_tokenizers * 2

train_questions
# Out:
#             id    qid1    qid2  \
# 0       216036  322068  322069
# 1       241554  353581  353582
# 2       208738  312815  312816
# 3       102714  104282   77231
# 4       397304  178955   34172
# ...        ...     ...     ...
# 323426  189944    8395   34814
# 323427  330730  110579  457526
# 323428  143114  226824  175127
# 323429   10918   21121   21122
# 323430   57378  100834  100835
#
#                                                 question1  \
# 0       How can I sell at Snapdeal? What are the terms...
# 1       Why are most prosecutors in American courts no...
# 2       What are some good government jobs without a c...
# 3       What would happen if humans no longer needed t...
# 4                          How do I shave my bikini line?
# ...                                                   ...
# 323426            Is it true that the US is funding ISIS?
# 323427            How do I play in share market in India?
# 323428  What is the difference between laundry deterge...
# 323429  Would you consider teaching as a full time job...
# 323430  What drugs are readily accessible in Canada ov...
#
#                                                 question2  is_duplicate  \
# 0       What are the payment terms for online marketpl...             0
# 1       Why does a country like USA where law enforcem...             0
# 2       Are there any good companies that hire smart p...             0
# 3       What would the world be like if humans didn't ...             1
# 4          What is the best way to shave the bikini area?             1
# ...                                                   ...           ...
# 323426         Is it really true that US is backing ISIS?             1
# 323427  How can I study and invest in the Indian share...             0
# 323428  How safe is it to use non-HE detergent in a HE...             0
# 323429    Would you consider teaching as a full time job?             1
# 323430  What legal drugs (i.e. bought 'over the counte...             0
#
#                                         question1_cleaned  \
# 0               How I sell Snapdeal What terms conditions
# 1       Why prosecutors American courts notoriously di...
# 2        What good government jobs without college degree
# 3            What would happen humans longer needed sleep
# 4                                 How I shave bikini line
# ...                                                   ...
# 323426                            Is true US funding ISIS
# 323427                      How I play share market India
# 323428  What difference laundry detergent bleach laund...
# 323429          Would consider teaching full time job Why
# 323430  What drugs readily accessible Canada counter r...
#
#                                         question2_cleaned  \
# 0       What payment terms online marketplaces like Fl...
# 1       Why country like USA law enforcements strict l...
# 2       Are good companies hire smart people without c...
# 3           What would world like humans didnt need sleep
# 4                         What best way shave bikini area
# ...                                                   ...
# 323426                     Is really true US backing ISIS
# 323427             How I study invest Indian share market
# 323428     How safe use nonHE detergent HE laundry washer
# 323429              Would consider teaching full time job
# 323430  What legal drugs ie bought counter cause loss ...
#
#                                               tokenizer_1  \
# 0       [4, 3, 522, 4905, 2, 466, 3146, 0, 0, 0, 0, 0,...
# 1       [5, 28363, 292, 4730, 32476, 12231, 1100, 145,...
# 2       [2, 14, 164, 334, 44, 125, 418, 0, 0, 0, 0, 0,...
# 3       [2, 15, 119, 475, 1192, 1143, 412, 0, 0, 0, 0,...
# 4       [4, 3, 3379, 6390, 702, 0, 0, 0, 0, 0, 0, 0, 0...
# ...                                                   ...
# 323426  [7, 180, 38, 1578, 1304, 0, 0, 0, 0, 0, 0, 0, ...
# 323427  [4, 3, 231, 676, 293, 10, 0, 0, 0, 0, 0, 0, 0,...
# 323428  [2, 28, 7495, 6195, 3493, 7495, 6195, 44, 3493...
# 323429  [15, 995, 2742, 623, 25, 54, 5, 0, 0, 0, 0, 0,...
# 323430  [2, 2156, 10635, 9057, 436, 3897, 2005, 887, 4...
#
#                                               tokenizer_2  \
# 0       [2, 1603, 466, 47, 14382, 13, 2223, 7716, 4905...
# 1       [5, 135, 13, 208, 404, 75956, 6164, 2008, 1221...
# 2       [42, 14, 181, 797, 770, 11, 44, 125, 418, 0, 0...
# 3       [2, 15, 50, 13, 475, 490, 92, 412, 0, 0, 0, 0,...
# 4       [2, 6, 18, 3379, 6390, 619, 0, 0, 0, 0, 0, 0, ...
# ...                                                   ...
# 323426  [7, 79, 180, 38, 10459, 1304, 0, 0, 0, 0, 0, 0...
# 323427  [4, 3, 150, 491, 37, 676, 293, 0, 0, 0, 0, 0, ...
# 323428  [4, 204, 32, 36566, 6195, 1289, 7495, 10332, 0...
# 323429  [15, 995, 2742, 623, 25, 54, 0, 0, 0, 0, 0, 0,...
# 323430  [2, 463, 2156, 2163, 2291, 3897, 382, 692, 857...
#
#                                                 tokenizer
# 0       [4, 3, 522, 4905, 2, 466, 3146, 0, 0, 0, 0, 0,...
# 1       [5, 28363, 292, 4730, 32476, 12231, 1100, 145,...
# 2       [2, 14, 164, 334, 44, 125, 418, 0, 0, 0, 0, 0,...
# 3       [2, 15, 119, 475, 1192, 1143, 412, 0, 0, 0, 0,...
# 4       [4, 3, 3379, 6390, 702, 0, 0, 0, 0, 0, 0, 0, 0...
# ...                                                   ...
# 323426  [7, 180, 38, 1578, 1304, 0, 0, 0, 0, 0, 0, 0, ...
# 323427  [4, 3, 231, 676, 293, 10, 0, 0, 0, 0, 0, 0, 0,...
# 323428  [2, 28, 7495, 6195, 3493, 7495, 6195, 44, 3493...
# 323429  [15, 995, 2742, 623, 25, 54, 5, 0, 0, 0, 0, 0,...
# 323430  [2, 2156, 10635, 9057, 436, 3897, 2005, 887, 4...
#
# [323431 rows x 11 columns]

# %%
train_questions[train_questions.columns[[3,4, 6, 7]]]
# Out:
#                                                 question1  \
# 0       How can I sell at Snapdeal? What are the terms...
# 1       Why are most prosecutors in American courts no...
# 2       What are some good government jobs without a c...
# 3       What would happen if humans no longer needed t...
# 4                          How do I shave my bikini line?
# ...                                                   ...
# 323426            Is it true that the US is funding ISIS?
# 323427            How do I play in share market in India?
# 323428  What is the difference between laundry deterge...
# 323429  Would you consider teaching as a full time job...
# 323430  What drugs are readily accessible in Canada ov...
#
#                                                 question2  \
# 0       What are the payment terms for online marketpl...
# 1       Why does a country like USA where law enforcem...
# 2       Are there any good companies that hire smart p...
# 3       What would the world be like if humans didn't ...
# 4          What is the best way to shave the bikini area?
# ...                                                   ...
# 323426         Is it really true that US is backing ISIS?
# 323427  How can I study and invest in the Indian share...
# 323428  How safe is it to use non-HE detergent in a HE...
# 323429    Would you consider teaching as a full time job?
# 323430  What legal drugs (i.e. bought 'over the counte...
#
#                                         question1_cleaned  \
# 0               How I sell Snapdeal What terms conditions
# 1       Why prosecutors American courts notoriously di...
# 2        What good government jobs without college degree
# 3            What would happen humans longer needed sleep
# 4                                 How I shave bikini line
# ...                                                   ...
# 323426                            Is true US funding ISIS
# 323427                      How I play share market India
# 323428  What difference laundry detergent bleach laund...
# 323429          Would consider teaching full time job Why
# 323430  What drugs readily accessible Canada counter r...
#
#                                         question2_cleaned
# 0       What payment terms online marketplaces like Fl...
# 1       Why country like USA law enforcements strict l...
# 2       Are good companies hire smart people without c...
# 3           What would world like humans didnt need sleep
# 4                         What best way shave bikini area
# ...                                                   ...
# 323426                     Is really true US backing ISIS
# 323427             How I study invest Indian share market
# 323428     How safe use nonHE detergent HE laundry washer
# 323429              Would consider teaching full time job
# 323430  What legal drugs ie bought counter cause loss ...
#
# [323431 rows x 4 columns]

# %% [markdown]
# # Model implementation
# We don't need all the information of the DataFrame, we will focus now on the "tokenizer" and "is_duplicate" column

# %%
y_train = train_questions[['is_duplicate']]
X_train = train_questions[['tokenizer']]
y_validation = validation_questions[['is_duplicate']]
X_validation = validation_questions[['tokenizer']]
y_test = test_questions[['is_duplicate']]
X_test = test_questions[['tokenizer']]

# padding X_train with a maximum length
X_train = sequence.pad_sequences(X_train.tokenizer, maxlen = m_len, padding='post', truncating='post')
X_validation = sequence.pad_sequences(X_validation.tokenizer, maxlen = m_len, padding='post', truncating='post')
X_test = sequence.pad_sequences(X_test.tokenizer, maxlen = m_len, padding='post', truncating='post')

# %%
# class weight
class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train['is_duplicate'].tolist())

class_weights = dict(zip(np.unique(y_train), class_weights))
class_weights
# Out:
# {0: 0.7919194738672034, 1: 1.3564005569348454}

# %% [markdown]
# ## Experiment 1

# %%
#defining the model
model = Sequential()
#adding embeedding layer
model.add(Embedding(num_distinct_words, 64))
#adding drop out layer
model.add(Dropout(0.15))
#LSTM layer
model.add(LSTM(16))
#adding sigmoid layer
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 64)          6188096
#
#  dropout_3 (Dropout)         (None, None, 64)          0
#
#  lstm_3 (LSTM)               (None, 16)                5184
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 6,193,297
# Trainable params: 6,193,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "LSTM16", X_train, y_train, X_validation, y_validation, epochs=5)
# Out:
# Epoch 1/5
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4957 - accuracy: 0.7598
# Epoch 1: val_loss improved from inf to 0.47950, saving model to /content/Models/LSTM16.h5
# 5054/5054 [==============================] - 416s 82ms/step - loss: 0.4957 - accuracy: 0.7598 - val_loss: 0.4795 - val_accuracy: 0.7697
# Epoch 2/5
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4258 - accuracy: 0.7991
# Epoch 2: val_loss improved from 0.47950 to 0.46797, saving model to /content/Models/LSTM16.h5
# 5054/5054 [==============================] - 411s 81ms/step - loss: 0.4258 - accuracy: 0.7991 - val_loss: 0.4680 - val_accuracy: 0.7788
# Epoch 3/5
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 0.8303
# Epoch 3: val_loss did not improve from 0.46797
# 5054/5054 [==============================] - 409s 81ms/step - loss: 0.3666 - accuracy: 0.8303 - val_loss: 0.4690 - val_accuracy: 0.7851
# Epoch 4/5
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8572
# Epoch 4: val_loss did not improve from 0.46797
# 5054/5054 [==============================] - 396s 78ms/step - loss: 0.3155 - accuracy: 0.8572 - val_loss: 0.4853 - val_accuracy: 0.7829
# Epoch 5/5
# 5054/5054 [==============================] - ETA: 0s - loss: 0.2744 - accuracy: 0.8765
# Epoch 5: val_loss did not improve from 0.46797
# 5054/5054 [==============================] - 397s 78ms/step - loss: 0.2744 - accuracy: 0.8765 - val_loss: 0.5199 - val_accuracy: 0.7799

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8306    0.8141    0.8223     25348
#            1     0.6976    0.7210    0.7091     15080
#
#     accuracy                         0.7794     40428
#    macro avg     0.7641    0.7675    0.7657     40428
# weighted avg     0.7810    0.7794    0.7801     40428

# %% [markdown]
# ## Experiment 2

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 64)          6188096
#
#  dropout_3 (Dropout)         (None, None, 64)          0
#
#  bidirectional_3 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,254,273
# Trainable params: 6,254,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.5026 - accuracy: 0.7527
# Epoch 1: val_loss improved from inf to 0.47357, saving model to /content/Models/BI_LSTM64_more_dropout.h5
# 5054/5054 [==============================] - 160s 32ms/step - loss: 0.5026 - accuracy: 0.7527 - val_loss: 0.4736 - val_accuracy: 0.7698
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4408 - accuracy: 0.7876
# Epoch 2: val_loss improved from 0.47357 to 0.45539, saving model to /content/Models/BI_LSTM64_more_dropout.h5
# 5054/5054 [==============================] - 153s 30ms/step - loss: 0.4408 - accuracy: 0.7876 - val_loss: 0.4554 - val_accuracy: 0.7816
# Epoch 3/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4007 - accuracy: 0.8109
# Epoch 3: val_loss improved from 0.45539 to 0.44500, saving model to /content/Models/BI_LSTM64_more_dropout.h5
# 5054/5054 [==============================] - 157s 31ms/step - loss: 0.4007 - accuracy: 0.8109 - val_loss: 0.4450 - val_accuracy: 0.7899
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3706 - accuracy: 0.8283
# Epoch 4: val_loss did not improve from 0.44500
# 5054/5054 [==============================] - 157s 31ms/step - loss: 0.3706 - accuracy: 0.8283 - val_loss: 0.4453 - val_accuracy: 0.7924
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3468 - accuracy: 0.8408
# Epoch 5: val_loss improved from 0.44500 to 0.44022, saving model to /content/Models/BI_LSTM64_more_dropout.h5
# 5054/5054 [==============================] - 153s 30ms/step - loss: 0.3468 - accuracy: 0.8408 - val_loss: 0.4402 - val_accuracy: 0.7956
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3253 - accuracy: 0.8515
# Epoch 6: val_loss did not improve from 0.44022
# 5054/5054 [==============================] - 161s 32ms/step - loss: 0.3253 - accuracy: 0.8515 - val_loss: 0.4413 - val_accuracy: 0.8007
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8604
# Epoch 7: val_loss did not improve from 0.44022
# 5054/5054 [==============================] - 154s 30ms/step - loss: 0.3092 - accuracy: 0.8604 - val_loss: 0.4468 - val_accuracy: 0.8039
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2946 - accuracy: 0.8678
# Epoch 8: val_loss did not improve from 0.44022
# 5054/5054 [==============================] - 162s 32ms/step - loss: 0.2946 - accuracy: 0.8678 - val_loss: 0.4543 - val_accuracy: 0.8001
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2823 - accuracy: 0.8744
# Epoch 9: val_loss did not improve from 0.44022
# 5054/5054 [==============================] - 157s 31ms/step - loss: 0.2823 - accuracy: 0.8744 - val_loss: 0.4490 - val_accuracy: 0.7989
# Epoch 10/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2701 - accuracy: 0.8799
# Epoch 10: val_loss did not improve from 0.44022
# 5054/5054 [==============================] - 159s 31ms/step - loss: 0.2701 - accuracy: 0.8799 - val_loss: 0.4618 - val_accuracy: 0.8025

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8588    0.8160    0.8369     25348
#            1     0.7146    0.7745    0.7434     15080
#
#     accuracy                         0.8005     40428
#    macro avg     0.7867    0.7953    0.7901     40428
# weighted avg     0.8050    0.8005    0.8020     40428

# %% [markdown]
# ## Experiment 3

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(layers.Dense(128, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, None, 64)          6188096
#
#  dropout_8 (Dropout)         (None, None, 64)          0
#
#  bidirectional_8 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_8 (Dense)             (None, 128)               16512
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,270,785
# Trainable params: 6,270,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Dense128", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.5136 - accuracy: 0.7470
# Epoch 1: val_loss improved from inf to 0.47939, saving model to /content/Models/BI_LSTM64_Dense128.h5
# 5054/5054 [==============================] - 160s 31ms/step - loss: 0.5136 - accuracy: 0.7470 - val_loss: 0.4794 - val_accuracy: 0.7654
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4487 - accuracy: 0.7840
# Epoch 2: val_loss improved from 0.47939 to 0.45630, saving model to /content/Models/BI_LSTM64_Dense128.h5
# 5054/5054 [==============================] - 156s 31ms/step - loss: 0.4487 - accuracy: 0.7840 - val_loss: 0.4563 - val_accuracy: 0.7818
# Epoch 3/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4106 - accuracy: 0.8054
# Epoch 3: val_loss improved from 0.45630 to 0.44706, saving model to /content/Models/BI_LSTM64_Dense128.h5
# 5054/5054 [==============================] - 152s 30ms/step - loss: 0.4106 - accuracy: 0.8054 - val_loss: 0.4471 - val_accuracy: 0.7893
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3807 - accuracy: 0.8221
# Epoch 4: val_loss improved from 0.44706 to 0.44332, saving model to /content/Models/BI_LSTM64_Dense128.h5
# 5054/5054 [==============================] - 152s 30ms/step - loss: 0.3807 - accuracy: 0.8221 - val_loss: 0.4433 - val_accuracy: 0.7928
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3564 - accuracy: 0.8352
# Epoch 5: val_loss did not improve from 0.44332
# 5054/5054 [==============================] - 155s 31ms/step - loss: 0.3564 - accuracy: 0.8352 - val_loss: 0.4525 - val_accuracy: 0.7944
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3369 - accuracy: 0.8455
# Epoch 6: val_loss improved from 0.44332 to 0.44272, saving model to /content/Models/BI_LSTM64_Dense128.h5
# 5054/5054 [==============================] - 155s 31ms/step - loss: 0.3369 - accuracy: 0.8455 - val_loss: 0.4427 - val_accuracy: 0.7973
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3191 - accuracy: 0.8549
# Epoch 7: val_loss did not improve from 0.44272
# 5054/5054 [==============================] - 151s 30ms/step - loss: 0.3191 - accuracy: 0.8549 - val_loss: 0.4520 - val_accuracy: 0.8017
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3033 - accuracy: 0.8625
# Epoch 8: val_loss did not improve from 0.44272
# 5054/5054 [==============================] - 151s 30ms/step - loss: 0.3033 - accuracy: 0.8625 - val_loss: 0.4553 - val_accuracy: 0.7981
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2910 - accuracy: 0.8685
# Epoch 9: val_loss did not improve from 0.44272
# 5054/5054 [==============================] - 151s 30ms/step - loss: 0.2910 - accuracy: 0.8685 - val_loss: 0.4753 - val_accuracy: 0.7971
# Epoch 10/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2790 - accuracy: 0.8749
# Epoch 10: val_loss did not improve from 0.44272
# 5054/5054 [==============================] - 153s 30ms/step - loss: 0.2790 - accuracy: 0.8749 - val_loss: 0.4868 - val_accuracy: 0.7983

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8575    0.8108    0.8335     25348
#            1     0.7086    0.7735    0.7397     15080
#
#     accuracy                         0.7969     40428
#    macro avg     0.7831    0.7922    0.7866     40428
# weighted avg     0.8020    0.7969    0.7985     40428

# %% [markdown]
# ## Experiment 4

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 32))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 32)          3094048
#
#  dropout_2 (Dropout)         (None, None, 32)          0
#
#  bidirectional_2 (Bidirectio  (None, 128)              49664
#  nal)
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,143,841
# Trainable params: 3,143,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Embedding32", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5050/5054 [============================>.] - ETA: 0s - loss: 0.5184 - accuracy: 0.7439
# Epoch 1: val_loss improved from inf to 0.48457, saving model to /content/Models/BI_LSTM64_Embedding32.h5
# 5054/5054 [==============================] - 60s 10ms/step - loss: 0.5183 - accuracy: 0.7439 - val_loss: 0.4846 - val_accuracy: 0.7649
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4610 - accuracy: 0.7779
# Epoch 2: val_loss improved from 0.48457 to 0.46910, saving model to /content/Models/BI_LSTM64_Embedding32.h5
# 5054/5054 [==============================] - 53s 10ms/step - loss: 0.4610 - accuracy: 0.7778 - val_loss: 0.4691 - val_accuracy: 0.7737
# Epoch 3/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.4302 - accuracy: 0.7937
# Epoch 3: val_loss improved from 0.46910 to 0.45800, saving model to /content/Models/BI_LSTM64_Embedding32.h5
# 5054/5054 [==============================] - 53s 11ms/step - loss: 0.4302 - accuracy: 0.7938 - val_loss: 0.4580 - val_accuracy: 0.7823
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4075 - accuracy: 0.8070
# Epoch 4: val_loss did not improve from 0.45800
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.4075 - accuracy: 0.8071 - val_loss: 0.4627 - val_accuracy: 0.7851
# Epoch 5/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.3872 - accuracy: 0.8182
# Epoch 5: val_loss did not improve from 0.45800
# 5054/5054 [==============================] - 51s 10ms/step - loss: 0.3872 - accuracy: 0.8182 - val_loss: 0.4588 - val_accuracy: 0.7838
# Epoch 6/10
# 5050/5054 [============================>.] - ETA: 0s - loss: 0.3704 - accuracy: 0.8279
# Epoch 6: val_loss improved from 0.45800 to 0.45463, saving model to /content/Models/BI_LSTM64_Embedding32.h5
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3704 - accuracy: 0.8279 - val_loss: 0.4546 - val_accuracy: 0.7865
# Epoch 7/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.3570 - accuracy: 0.8346
# Epoch 7: val_loss improved from 0.45463 to 0.45205, saving model to /content/Models/BI_LSTM64_Embedding32.h5
# 5054/5054 [==============================] - 53s 10ms/step - loss: 0.3570 - accuracy: 0.8346 - val_loss: 0.4521 - val_accuracy: 0.7928
# Epoch 8/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.3445 - accuracy: 0.8413
# Epoch 8: val_loss did not improve from 0.45205
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3445 - accuracy: 0.8413 - val_loss: 0.4575 - val_accuracy: 0.7895
# Epoch 9/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.3342 - accuracy: 0.8469
# Epoch 9: val_loss did not improve from 0.45205
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3342 - accuracy: 0.8469 - val_loss: 0.4535 - val_accuracy: 0.7924
# Epoch 10/10
# 5050/5054 [============================>.] - ETA: 0s - loss: 0.3255 - accuracy: 0.8512
# Epoch 10: val_loss did not improve from 0.45205
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3255 - accuracy: 0.8512 - val_loss: 0.4641 - val_accuracy: 0.7895

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8485    0.8018    0.8245     25348
#            1     0.6951    0.7593    0.7258     15080
#
#     accuracy                         0.7860     40428
#    macro avg     0.7718    0.7806    0.7751     40428
# weighted avg     0.7913    0.7860    0.7877     40428

# %% [markdown]
# ## Experiment 5

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 128))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, None, 128)         12376192
#
#  dropout_8 (Dropout)         (None, None, 128)         0
#
#  bidirectional_8 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 12,475,137
# Trainable params: 12,475,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Embedding128", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.5099 - accuracy: 0.7491
# Epoch 1: val_loss improved from inf to 0.46869, saving model to /content/Models/BI_LSTM64_Embedding128.h5
# 5054/5054 [==============================] - 83s 16ms/step - loss: 0.5099 - accuracy: 0.7492 - val_loss: 0.4687 - val_accuracy: 0.7731
# Epoch 2/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.4344 - accuracy: 0.7936
# Epoch 2: val_loss improved from 0.46869 to 0.45150, saving model to /content/Models/BI_LSTM64_Embedding128.h5
# 5054/5054 [==============================] - 78s 15ms/step - loss: 0.4345 - accuracy: 0.7936 - val_loss: 0.4515 - val_accuracy: 0.7838
# Epoch 3/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3869 - accuracy: 0.8205
# Epoch 3: val_loss improved from 0.45150 to 0.44885, saving model to /content/Models/BI_LSTM64_Embedding128.h5
# 5054/5054 [==============================] - 77s 15ms/step - loss: 0.3869 - accuracy: 0.8205 - val_loss: 0.4488 - val_accuracy: 0.7884
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3490 - accuracy: 0.8402
# Epoch 4: val_loss improved from 0.44885 to 0.44850, saving model to /content/Models/BI_LSTM64_Embedding128.h5
# 5054/5054 [==============================] - 78s 15ms/step - loss: 0.3490 - accuracy: 0.8402 - val_loss: 0.4485 - val_accuracy: 0.7910
# Epoch 5/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.3188 - accuracy: 0.8553
# Epoch 5: val_loss did not improve from 0.44850
# 5054/5054 [==============================] - 78s 15ms/step - loss: 0.3188 - accuracy: 0.8553 - val_loss: 0.4632 - val_accuracy: 0.7952
# Epoch 6/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.2948 - accuracy: 0.8680
# Epoch 6: val_loss did not improve from 0.44850
# 5054/5054 [==============================] - 77s 15ms/step - loss: 0.2948 - accuracy: 0.8680 - val_loss: 0.4943 - val_accuracy: 0.7829
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2754 - accuracy: 0.8771
# Epoch 7: val_loss did not improve from 0.44850
# 5054/5054 [==============================] - 77s 15ms/step - loss: 0.2754 - accuracy: 0.8771 - val_loss: 0.5004 - val_accuracy: 0.7912
# Epoch 8/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.8845
# Epoch 8: val_loss did not improve from 0.44850
# 5054/5054 [==============================] - 77s 15ms/step - loss: 0.2591 - accuracy: 0.8845 - val_loss: 0.5120 - val_accuracy: 0.7912
# Epoch 9/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.8908
# Epoch 9: val_loss did not improve from 0.44850
# 5054/5054 [==============================] - 77s 15ms/step - loss: 0.2465 - accuracy: 0.8908 - val_loss: 0.5169 - val_accuracy: 0.7941

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8389    0.8155    0.8270     25348
#            1     0.7038    0.7368    0.7199     15080
#
#     accuracy                         0.7861     40428
#    macro avg     0.7713    0.7761    0.7735     40428
# weighted avg     0.7885    0.7861    0.7871     40428

# %% [markdown]
# ## Experiment 6

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(32)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 64)          6188096
#
#  dropout (Dropout)           (None, None, 64)          0
#
#  bidirectional (Bidirectiona  (None, 64)               24832
#  l)
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 6,212,993
# Trainable params: 6,212,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM32", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7455
# Epoch 1: val_loss improved from inf to 0.48247, saving model to /content/Models/BI_LSTM32.h5
# 5054/5054 [==============================] - 158s 30ms/step - loss: 0.5147 - accuracy: 0.7455 - val_loss: 0.4825 - val_accuracy: 0.7679
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4480 - accuracy: 0.7846
# Epoch 2: val_loss improved from 0.48247 to 0.45848, saving model to /content/Models/BI_LSTM32.h5
# 5054/5054 [==============================] - 148s 29ms/step - loss: 0.4480 - accuracy: 0.7846 - val_loss: 0.4585 - val_accuracy: 0.7808
# Epoch 3/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4101 - accuracy: 0.8044
# Epoch 3: val_loss improved from 0.45848 to 0.45071, saving model to /content/Models/BI_LSTM32.h5
# 5054/5054 [==============================] - 148s 29ms/step - loss: 0.4101 - accuracy: 0.8044 - val_loss: 0.4507 - val_accuracy: 0.7874
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3814 - accuracy: 0.8212
# Epoch 4: val_loss improved from 0.45071 to 0.44667, saving model to /content/Models/BI_LSTM32.h5
# 5054/5054 [==============================] - 148s 29ms/step - loss: 0.3814 - accuracy: 0.8212 - val_loss: 0.4467 - val_accuracy: 0.7927
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3581 - accuracy: 0.8336
# Epoch 5: val_loss did not improve from 0.44667
# 5054/5054 [==============================] - 148s 29ms/step - loss: 0.3581 - accuracy: 0.8336 - val_loss: 0.4536 - val_accuracy: 0.7922
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3371 - accuracy: 0.8454
# Epoch 6: val_loss improved from 0.44667 to 0.44532, saving model to /content/Models/BI_LSTM32.h5
# 5054/5054 [==============================] - 148s 29ms/step - loss: 0.3371 - accuracy: 0.8454 - val_loss: 0.4453 - val_accuracy: 0.7966
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3202 - accuracy: 0.8542
# Epoch 7: val_loss did not improve from 0.44532
# 5054/5054 [==============================] - 147s 29ms/step - loss: 0.3202 - accuracy: 0.8542 - val_loss: 0.4622 - val_accuracy: 0.7968
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3065 - accuracy: 0.8610
# Epoch 8: val_loss did not improve from 0.44532
# 5054/5054 [==============================] - 147s 29ms/step - loss: 0.3065 - accuracy: 0.8610 - val_loss: 0.4553 - val_accuracy: 0.8012
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2924 - accuracy: 0.8688
# Epoch 9: val_loss did not improve from 0.44532
# 5054/5054 [==============================] - 147s 29ms/step - loss: 0.2925 - accuracy: 0.8688 - val_loss: 0.4683 - val_accuracy: 0.8005
# Epoch 10/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2811 - accuracy: 0.8742
# Epoch 10: val_loss did not improve from 0.44532
# 5054/5054 [==============================] - 147s 29ms/step - loss: 0.2811 - accuracy: 0.8742 - val_loss: 0.4747 - val_accuracy: 0.7950

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8604    0.8021    0.8302     25348
#            1     0.7013    0.7812    0.7391     15080
#
#     accuracy                         0.7943     40428
#    macro avg     0.7808    0.7916    0.7846     40428
# weighted avg     0.8010    0.7943    0.7962     40428

# %% [markdown]
# ## Experiment 7

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 32))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(32)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 32)          3094048
#
#  dropout_1 (Dropout)         (None, None, 32)          0
#
#  bidirectional_1 (Bidirectio  (None, 64)               16640
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 3,110,753
# Trainable params: 3,110,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM32_Embedding32", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.5180 - accuracy: 0.7442
# Epoch 1: val_loss improved from inf to 0.48528, saving model to /content/Models/BI_LSTM32_Embedding32.h5
# 5054/5054 [==============================] - 135s 26ms/step - loss: 0.5180 - accuracy: 0.7442 - val_loss: 0.4853 - val_accuracy: 0.7645
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4602 - accuracy: 0.7776
# Epoch 2: val_loss improved from 0.48528 to 0.46838, saving model to /content/Models/BI_LSTM32_Embedding32.h5
# 5054/5054 [==============================] - 130s 26ms/step - loss: 0.4602 - accuracy: 0.7776 - val_loss: 0.4684 - val_accuracy: 0.7713
# Epoch 3/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4303 - accuracy: 0.7936
# Epoch 3: val_loss improved from 0.46838 to 0.45548, saving model to /content/Models/BI_LSTM32_Embedding32.h5
# 5054/5054 [==============================] - 130s 26ms/step - loss: 0.4303 - accuracy: 0.7936 - val_loss: 0.4555 - val_accuracy: 0.7821
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4061 - accuracy: 0.8084
# Epoch 4: val_loss did not improve from 0.45548
# 5054/5054 [==============================] - 129s 26ms/step - loss: 0.4061 - accuracy: 0.8084 - val_loss: 0.4579 - val_accuracy: 0.7844
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3854 - accuracy: 0.8188
# Epoch 5: val_loss improved from 0.45548 to 0.45194, saving model to /content/Models/BI_LSTM32_Embedding32.h5
# 5054/5054 [==============================] - 129s 26ms/step - loss: 0.3854 - accuracy: 0.8188 - val_loss: 0.4519 - val_accuracy: 0.7877
# Epoch 6/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3693 - accuracy: 0.8279
# Epoch 6: val_loss did not improve from 0.45194
# 5054/5054 [==============================] - 128s 25ms/step - loss: 0.3693 - accuracy: 0.8279 - val_loss: 0.4540 - val_accuracy: 0.7889
# Epoch 7/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.3554 - accuracy: 0.8353
# Epoch 7: val_loss improved from 0.45194 to 0.44760, saving model to /content/Models/BI_LSTM32_Embedding32.h5
# 5054/5054 [==============================] - 128s 25ms/step - loss: 0.3554 - accuracy: 0.8353 - val_loss: 0.4476 - val_accuracy: 0.7914
# Epoch 8/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3439 - accuracy: 0.8417
# Epoch 8: val_loss did not improve from 0.44760
# 5054/5054 [==============================] - 128s 25ms/step - loss: 0.3439 - accuracy: 0.8417 - val_loss: 0.4490 - val_accuracy: 0.7963
# Epoch 9/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.3332 - accuracy: 0.8469
# Epoch 9: val_loss did not improve from 0.44760
# 5054/5054 [==============================] - 127s 25ms/step - loss: 0.3332 - accuracy: 0.8469 - val_loss: 0.4563 - val_accuracy: 0.7969
# Epoch 10/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.8518
# Epoch 10: val_loss did not improve from 0.44760
# 5054/5054 [==============================] - 128s 25ms/step - loss: 0.3239 - accuracy: 0.8518 - val_loss: 0.4585 - val_accuracy: 0.7949

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8529    0.8071    0.8294     25348
#            1     0.7026    0.7661    0.7330     15080
#
#     accuracy                         0.7918     40428
#    macro avg     0.7778    0.7866    0.7812     40428
# weighted avg     0.7969    0.7918    0.7934     40428

# %% [markdown]
# ## Experiment 8

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 16))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 16)          1547024
#
#  dropout_1 (Dropout)         (None, None, 16)          0
#
#  bidirectional_1 (Bidirectio  (None, 128)              41472
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 1,588,625
# Trainable params: 1,588,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_embedding16", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.5247 - accuracy: 0.7402
# Epoch 1: val_loss improved from inf to 0.49089, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 153s 29ms/step - loss: 0.5247 - accuracy: 0.7403 - val_loss: 0.4909 - val_accuracy: 0.7639
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4700 - accuracy: 0.7745
# Epoch 2: val_loss improved from 0.49089 to 0.47358, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 145s 29ms/step - loss: 0.4700 - accuracy: 0.7744 - val_loss: 0.4736 - val_accuracy: 0.7675
# Epoch 3/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4455 - accuracy: 0.7865
# Epoch 3: val_loss improved from 0.47358 to 0.47331, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 145s 29ms/step - loss: 0.4455 - accuracy: 0.7865 - val_loss: 0.4733 - val_accuracy: 0.7741
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4272 - accuracy: 0.7956
# Epoch 4: val_loss improved from 0.47331 to 0.46926, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 145s 29ms/step - loss: 0.4272 - accuracy: 0.7956 - val_loss: 0.4693 - val_accuracy: 0.7778
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4121 - accuracy: 0.8039
# Epoch 5: val_loss improved from 0.46926 to 0.45623, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 145s 29ms/step - loss: 0.4121 - accuracy: 0.8039 - val_loss: 0.4562 - val_accuracy: 0.7815
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3982 - accuracy: 0.8114
# Epoch 6: val_loss improved from 0.45623 to 0.45464, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 145s 29ms/step - loss: 0.3982 - accuracy: 0.8114 - val_loss: 0.4546 - val_accuracy: 0.7857
# Epoch 7/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3882 - accuracy: 0.8166
# Epoch 7: val_loss improved from 0.45464 to 0.45225, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 146s 29ms/step - loss: 0.3882 - accuracy: 0.8166 - val_loss: 0.4523 - val_accuracy: 0.7882
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3774 - accuracy: 0.8216
# Epoch 8: val_loss did not improve from 0.45225
# 5054/5054 [==============================] - 145s 29ms/step - loss: 0.3774 - accuracy: 0.8216 - val_loss: 0.4533 - val_accuracy: 0.7851
# Epoch 9/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3687 - accuracy: 0.8274
# Epoch 9: val_loss improved from 0.45225 to 0.44688, saving model to /content/Models/BI_LSTM64_embedding16.h5
# 5054/5054 [==============================] - 144s 28ms/step - loss: 0.3687 - accuracy: 0.8274 - val_loss: 0.4469 - val_accuracy: 0.7905
# Epoch 10/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3615 - accuracy: 0.8319
# Epoch 10: val_loss did not improve from 0.44688
# 5054/5054 [==============================] - 144s 28ms/step - loss: 0.3615 - accuracy: 0.8319 - val_loss: 0.4489 - val_accuracy: 0.7891

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8364    0.8174    0.8268     25348
#            1     0.7044    0.7313    0.7176     15080
#
#     accuracy                         0.7853     40428
#    macro avg     0.7704    0.7744    0.7722     40428
# weighted avg     0.7872    0.7853    0.7861     40428

# %% [markdown]
# ## Class weight

# %% [markdown]
# ### Experiment 1

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 64)          6188096
#
#  dropout_6 (Dropout)         (None, None, 64)          0
#
#  bidirectional_6 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,254,273
# Trainable params: 6,254,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_weights", X_train, y_train, X_validation, y_validation, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.5347 - accuracy: 0.7277
# Epoch 1: val_loss improved from inf to 0.49670, saving model to /content/Models/BI_LSTM64_weights.h5
# 5054/5054 [==============================] - 63s 12ms/step - loss: 0.5347 - accuracy: 0.7277 - val_loss: 0.4967 - val_accuracy: 0.7511
# Epoch 2/10
# 5050/5054 [============================>.] - ETA: 0s - loss: 0.4635 - accuracy: 0.7727
# Epoch 2: val_loss improved from 0.49670 to 0.47433, saving model to /content/Models/BI_LSTM64_weights.h5
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.4635 - accuracy: 0.7727 - val_loss: 0.4743 - val_accuracy: 0.7737
# Epoch 3/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4195 - accuracy: 0.7975
# Epoch 3: val_loss did not improve from 0.47433
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.4195 - accuracy: 0.7975 - val_loss: 0.4744 - val_accuracy: 0.7691
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3860 - accuracy: 0.8164
# Epoch 4: val_loss improved from 0.47433 to 0.46741, saving model to /content/Models/BI_LSTM64_weights.h5
# 5054/5054 [==============================] - 60s 12ms/step - loss: 0.3860 - accuracy: 0.8164 - val_loss: 0.4674 - val_accuracy: 0.7740
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.8298
# Epoch 5: val_loss did not improve from 0.46741
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.3606 - accuracy: 0.8298 - val_loss: 0.4763 - val_accuracy: 0.7697
# Epoch 6/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.8411
# Epoch 6: val_loss did not improve from 0.46741
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.3390 - accuracy: 0.8411 - val_loss: 0.4724 - val_accuracy: 0.7767
# Epoch 7/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.3200 - accuracy: 0.8512
# Epoch 7: val_loss did not improve from 0.46741
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.3201 - accuracy: 0.8512 - val_loss: 0.4852 - val_accuracy: 0.7764
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3049 - accuracy: 0.8587
# Epoch 8: val_loss did not improve from 0.46741
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.3049 - accuracy: 0.8587 - val_loss: 0.5005 - val_accuracy: 0.7710
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2905 - accuracy: 0.8665
# Epoch 9: val_loss did not improve from 0.46741
# 5054/5054 [==============================] - 59s 12ms/step - loss: 0.2905 - accuracy: 0.8665 - val_loss: 0.4960 - val_accuracy: 0.7792

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8754    0.7495    0.8075     25348
#            1     0.6609    0.8206    0.7321     15080
#
#     accuracy                         0.7760     40428
#    macro avg     0.7681    0.7851    0.7698     40428
# weighted avg     0.7954    0.7760    0.7794     40428

# %% [markdown]
# ### Experiment 2

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(layers.Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 64)          6188096
#
#  bidirectional_2 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,270,785
# Trainable params: 6,270,785
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Dense128_weights", X_train, y_train, X_validation, y_validation, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.5264 - accuracy: 0.7352
# Epoch 1: val_loss improved from inf to 0.49831, saving model to /content/Models/BI_LSTM64_Dense128_weights.h5
# 5054/5054 [==============================] - 64s 12ms/step - loss: 0.5264 - accuracy: 0.7352 - val_loss: 0.4983 - val_accuracy: 0.7585
# Epoch 2/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.4140 - accuracy: 0.8037
# Epoch 2: val_loss improved from 0.49831 to 0.46367, saving model to /content/Models/BI_LSTM64_Dense128_weights.h5
# 5054/5054 [==============================] - 60s 12ms/step - loss: 0.4140 - accuracy: 0.8037 - val_loss: 0.4637 - val_accuracy: 0.7742
# Epoch 3/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.3296 - accuracy: 0.8490
# Epoch 3: val_loss did not improve from 0.46367
# 5054/5054 [==============================] - 60s 12ms/step - loss: 0.3296 - accuracy: 0.8489 - val_loss: 0.4700 - val_accuracy: 0.7916
# Epoch 4/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.8819
# Epoch 4: val_loss did not improve from 0.46367
# 5054/5054 [==============================] - 60s 12ms/step - loss: 0.2635 - accuracy: 0.8819 - val_loss: 0.4815 - val_accuracy: 0.7855
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2136 - accuracy: 0.9050
# Epoch 5: val_loss did not improve from 0.46367
# 5054/5054 [==============================] - 60s 12ms/step - loss: 0.2136 - accuracy: 0.9050 - val_loss: 0.5421 - val_accuracy: 0.7992
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.1765 - accuracy: 0.9221
# Epoch 6: val_loss did not improve from 0.46367
# 5054/5054 [==============================] - 63s 12ms/step - loss: 0.1765 - accuracy: 0.9221 - val_loss: 0.6023 - val_accuracy: 0.7888
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.1496 - accuracy: 0.9345
# Epoch 7: val_loss did not improve from 0.46367
# 5054/5054 [==============================] - 68s 14ms/step - loss: 0.1496 - accuracy: 0.9345 - val_loss: 0.6742 - val_accuracy: 0.7911

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8788    0.7737    0.8229     25348
#            1     0.6833    0.8206    0.7456     15080
#
#     accuracy                         0.7912     40428
#    macro avg     0.7810    0.7971    0.7843     40428
# weighted avg     0.8058    0.7912    0.7941     40428

# %% [markdown]
# ### Experiment 3

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 32))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, None, 32)          3094048
#
#  dropout_5 (Dropout)         (None, None, 32)          0
#
#  bidirectional_5 (Bidirectio  (None, 128)              49664
#  nal)
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,143,841
# Trainable params: 3,143,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Embedding32_weights", X_train, y_train, X_validation, y_validation, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.7241
# Epoch 1: val_loss improved from inf to 0.50344, saving model to /content/Models/BI_LSTM64_Embedding32_weights.h5
# 5054/5054 [==============================] - 56s 11ms/step - loss: 0.5420 - accuracy: 0.7241 - val_loss: 0.5034 - val_accuracy: 0.7544
# Epoch 2/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.4775 - accuracy: 0.7667
# Epoch 2: val_loss improved from 0.50344 to 0.49768, saving model to /content/Models/BI_LSTM64_Embedding32_weights.h5
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.4775 - accuracy: 0.7667 - val_loss: 0.4977 - val_accuracy: 0.7543
# Epoch 3/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.4423 - accuracy: 0.7856
# Epoch 3: val_loss improved from 0.49768 to 0.49008, saving model to /content/Models/BI_LSTM64_Embedding32_weights.h5
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.4423 - accuracy: 0.7856 - val_loss: 0.4901 - val_accuracy: 0.7598
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4168 - accuracy: 0.7990
# Epoch 4: val_loss did not improve from 0.49008
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.4168 - accuracy: 0.7990 - val_loss: 0.4984 - val_accuracy: 0.7554
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3964 - accuracy: 0.8102
# Epoch 5: val_loss improved from 0.49008 to 0.47968, saving model to /content/Models/BI_LSTM64_Embedding32_weights.h5
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3964 - accuracy: 0.8102 - val_loss: 0.4797 - val_accuracy: 0.7619
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3797 - accuracy: 0.8191
# Epoch 6: val_loss did not improve from 0.47968
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3797 - accuracy: 0.8191 - val_loss: 0.4875 - val_accuracy: 0.7639
# Epoch 7/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3652 - accuracy: 0.8271
# Epoch 7: val_loss did not improve from 0.47968
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3652 - accuracy: 0.8271 - val_loss: 0.4875 - val_accuracy: 0.7594
# Epoch 8/10
# 5050/5054 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8340
# Epoch 8: val_loss improved from 0.47968 to 0.47213, saving model to /content/Models/BI_LSTM64_Embedding32_weights.h5
# 5054/5054 [==============================] - 52s 10ms/step - loss: 0.3523 - accuracy: 0.8340 - val_loss: 0.4721 - val_accuracy: 0.7737
# Epoch 9/10
# 5049/5054 [============================>.] - ETA: 0s - loss: 0.3421 - accuracy: 0.8395
# Epoch 9: val_loss did not improve from 0.47213
# 5054/5054 [==============================] - 51s 10ms/step - loss: 0.3421 - accuracy: 0.8395 - val_loss: 0.5243 - val_accuracy: 0.7649
# Epoch 10/10
# 5050/5054 [============================>.] - ETA: 0s - loss: 0.3312 - accuracy: 0.8451
# Epoch 10: val_loss did not improve from 0.47213
# 5054/5054 [==============================] - 51s 10ms/step - loss: 0.3312 - accuracy: 0.8451 - val_loss: 0.4880 - val_accuracy: 0.7743

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8748    0.7394    0.8014     25348
#            1     0.6524    0.8221    0.7275     15080
#
#     accuracy                         0.7702     40428
#    macro avg     0.7636    0.7807    0.7644     40428
# weighted avg     0.7918    0.7702    0.7738     40428

# %% [markdown]
# ### Experiment 4

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 128))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, None, 128)         12376192
#
#  dropout_9 (Dropout)         (None, None, 128)         0
#
#  bidirectional_9 (Bidirectio  (None, 128)              98816
#  nal)
#
#  dense_11 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 12,475,137
# Trainable params: 12,475,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Embedding128_weights", X_train, y_train, X_validation, y_validation, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 5052/5054 [============================>.] - ETA: 0s - loss: 0.5313 - accuracy: 0.7303
# Epoch 1: val_loss improved from inf to 0.49470, saving model to /content/Models/BI_LSTM64_Embedding128_weights.h5
# 5054/5054 [==============================] - 91s 17ms/step - loss: 0.5313 - accuracy: 0.7303 - val_loss: 0.4947 - val_accuracy: 0.7540
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4488 - accuracy: 0.7815
# Epoch 2: val_loss improved from 0.49470 to 0.48714, saving model to /content/Models/BI_LSTM64_Embedding128_weights.h5
# 5054/5054 [==============================] - 82s 16ms/step - loss: 0.4488 - accuracy: 0.7815 - val_loss: 0.4871 - val_accuracy: 0.7564
# Epoch 3/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3952 - accuracy: 0.8112
# Epoch 3: val_loss improved from 0.48714 to 0.47384, saving model to /content/Models/BI_LSTM64_Embedding128_weights.h5
# 5054/5054 [==============================] - 81s 16ms/step - loss: 0.3952 - accuracy: 0.8112 - val_loss: 0.4738 - val_accuracy: 0.7734
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3539 - accuracy: 0.8340
# Epoch 4: val_loss improved from 0.47384 to 0.45952, saving model to /content/Models/BI_LSTM64_Embedding128_weights.h5
# 5054/5054 [==============================] - 81s 16ms/step - loss: 0.3539 - accuracy: 0.8340 - val_loss: 0.4595 - val_accuracy: 0.7845
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3209 - accuracy: 0.8516
# Epoch 5: val_loss did not improve from 0.45952
# 5054/5054 [==============================] - 81s 16ms/step - loss: 0.3209 - accuracy: 0.8516 - val_loss: 0.4862 - val_accuracy: 0.7774
# Epoch 6/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.2947 - accuracy: 0.8654
# Epoch 6: val_loss did not improve from 0.45952
# 5054/5054 [==============================] - 81s 16ms/step - loss: 0.2947 - accuracy: 0.8654 - val_loss: 0.4697 - val_accuracy: 0.7924
# Epoch 7/10
# 5051/5054 [============================>.] - ETA: 0s - loss: 0.2720 - accuracy: 0.8757
# Epoch 7: val_loss did not improve from 0.45952
# 5054/5054 [==============================] - 82s 16ms/step - loss: 0.2720 - accuracy: 0.8757 - val_loss: 0.5234 - val_accuracy: 0.7657
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2554 - accuracy: 0.8845
# Epoch 8: val_loss did not improve from 0.45952
# 5054/5054 [==============================] - 81s 16ms/step - loss: 0.2554 - accuracy: 0.8845 - val_loss: 0.5102 - val_accuracy: 0.7868
# Epoch 9/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.8915
# Epoch 9: val_loss did not improve from 0.45952
# 5054/5054 [==============================] - 81s 16ms/step - loss: 0.2409 - accuracy: 0.8915 - val_loss: 0.5333 - val_accuracy: 0.7845

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8804    0.7587    0.8150     25348
#            1     0.6709    0.8268    0.7407     15080
#
#     accuracy                         0.7841     40428
#    macro avg     0.7756    0.7927    0.7779     40428
# weighted avg     0.8023    0.7841    0.7873     40428

# %% [markdown]
# ## Attention

# %% [markdown]
# ### Experiment 1

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
model.add(Attention(32))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 64)          6188096
#
#  dropout_1 (Dropout)         (None, None, 64)          0
#
#  bidirectional_1 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  attention_1 (Attention)     (None, 32)                24576
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 6,278,753
# Trainable params: 6,278,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Attention32", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.5159 - accuracy: 0.7437
# Epoch 1: val_loss improved from inf to 0.49115, saving model to /content/Models/BI_LSTM64_Attention32.h5
# 5054/5054 [==============================] - 183s 34ms/step - loss: 0.5159 - accuracy: 0.7437 - val_loss: 0.4911 - val_accuracy: 0.7621
# Epoch 2/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4578 - accuracy: 0.7787
# Epoch 2: val_loss improved from 0.49115 to 0.47017, saving model to /content/Models/BI_LSTM64_Attention32.h5
# 5054/5054 [==============================] - 172s 34ms/step - loss: 0.4578 - accuracy: 0.7787 - val_loss: 0.4702 - val_accuracy: 0.7715
# Epoch 3/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4250 - accuracy: 0.7957
# Epoch 3: val_loss improved from 0.47017 to 0.45957, saving model to /content/Models/BI_LSTM64_Attention32.h5
# 5054/5054 [==============================] - 171s 34ms/step - loss: 0.4250 - accuracy: 0.7957 - val_loss: 0.4596 - val_accuracy: 0.7820
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3964 - accuracy: 0.8106
# Epoch 4: val_loss improved from 0.45957 to 0.45334, saving model to /content/Models/BI_LSTM64_Attention32.h5
# 5054/5054 [==============================] - 171s 34ms/step - loss: 0.3964 - accuracy: 0.8106 - val_loss: 0.4533 - val_accuracy: 0.7865
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3725 - accuracy: 0.8253
# Epoch 5: val_loss did not improve from 0.45334
# 5054/5054 [==============================] - 167s 33ms/step - loss: 0.3726 - accuracy: 0.8252 - val_loss: 0.4550 - val_accuracy: 0.7876
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3525 - accuracy: 0.8358
# Epoch 6: val_loss improved from 0.45334 to 0.44737, saving model to /content/Models/BI_LSTM64_Attention32.h5
# 5054/5054 [==============================] - 169s 33ms/step - loss: 0.3525 - accuracy: 0.8358 - val_loss: 0.4474 - val_accuracy: 0.7889
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3336 - accuracy: 0.8465
# Epoch 7: val_loss did not improve from 0.44737
# 5054/5054 [==============================] - 164s 32ms/step - loss: 0.3336 - accuracy: 0.8464 - val_loss: 0.4550 - val_accuracy: 0.7892
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3182 - accuracy: 0.8543
# Epoch 8: val_loss did not improve from 0.44737
# 5054/5054 [==============================] - 166s 33ms/step - loss: 0.3182 - accuracy: 0.8543 - val_loss: 0.4648 - val_accuracy: 0.7914
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3046 - accuracy: 0.8619
# Epoch 9: val_loss did not improve from 0.44737
# 5054/5054 [==============================] - 167s 33ms/step - loss: 0.3046 - accuracy: 0.8619 - val_loss: 0.4625 - val_accuracy: 0.7926
# Epoch 10/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.8672
# Epoch 10: val_loss did not improve from 0.44737
# 5054/5054 [==============================] - 165s 33ms/step - loss: 0.2933 - accuracy: 0.8672 - val_loss: 0.4678 - val_accuracy: 0.7945

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8477    0.8155    0.8313     25348
#            1     0.7085    0.7537    0.7304     15080
#
#     accuracy                         0.7925     40428
#    macro avg     0.7781    0.7846    0.7809     40428
# weighted avg     0.7958    0.7925    0.7937     40428

# %% [markdown]
# ### Experiment 2

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
model.add(Attention(32))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 64)          6188096
#
#  dropout_4 (Dropout)         (None, None, 64)          0
#
#  bidirectional_4 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  attention_4 (Attention)     (None, 32)                24576
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 6,278,753
# Trainable params: 6,278,753
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Attention32_weights", X_train, y_train, X_validation, y_validation, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7214
# Epoch 1: val_loss improved from inf to 0.52066, saving model to /content/Models/BI_LSTM64_Attention32_weights.h5
# 5054/5054 [==============================] - 176s 34ms/step - loss: 0.5392 - accuracy: 0.7214 - val_loss: 0.5207 - val_accuracy: 0.7390
# Epoch 2/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.4752 - accuracy: 0.7626
# Epoch 2: val_loss improved from 0.52066 to 0.48015, saving model to /content/Models/BI_LSTM64_Attention32_weights.h5
# 5054/5054 [==============================] - 174s 34ms/step - loss: 0.4752 - accuracy: 0.7626 - val_loss: 0.4802 - val_accuracy: 0.7642
# Epoch 3/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.7827
# Epoch 3: val_loss did not improve from 0.48015
# 5054/5054 [==============================] - 174s 34ms/step - loss: 0.4391 - accuracy: 0.7827 - val_loss: 0.4944 - val_accuracy: 0.7585
# Epoch 4/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4097 - accuracy: 0.7995
# Epoch 4: val_loss improved from 0.48015 to 0.47980, saving model to /content/Models/BI_LSTM64_Attention32_weights.h5
# 5054/5054 [==============================] - 176s 35ms/step - loss: 0.4097 - accuracy: 0.7995 - val_loss: 0.4798 - val_accuracy: 0.7637
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3844 - accuracy: 0.8137
# Epoch 5: val_loss did not improve from 0.47980
# 5054/5054 [==============================] - 182s 36ms/step - loss: 0.3844 - accuracy: 0.8137 - val_loss: 0.5024 - val_accuracy: 0.7529
# Epoch 6/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.8260
# Epoch 6: val_loss did not improve from 0.47980
# 5054/5054 [==============================] - 185s 37ms/step - loss: 0.3628 - accuracy: 0.8260 - val_loss: 0.4960 - val_accuracy: 0.7633
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3434 - accuracy: 0.8365
# Epoch 7: val_loss did not improve from 0.47980
# 5054/5054 [==============================] - 174s 35ms/step - loss: 0.3434 - accuracy: 0.8365 - val_loss: 0.4811 - val_accuracy: 0.7691
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3268 - accuracy: 0.8463
# Epoch 8: val_loss did not improve from 0.47980
# 5054/5054 [==============================] - 172s 34ms/step - loss: 0.3268 - accuracy: 0.8463 - val_loss: 0.4987 - val_accuracy: 0.7719
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3132 - accuracy: 0.8533
# Epoch 9: val_loss did not improve from 0.47980
# 5054/5054 [==============================] - 172s 34ms/step - loss: 0.3132 - accuracy: 0.8533 - val_loss: 0.5113 - val_accuracy: 0.7611

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8820    0.7163    0.7905     25348
#            1     0.6375    0.8389    0.7245     15080
#
#     accuracy                         0.7620     40428
#    macro avg     0.7597    0.7776    0.7575     40428
# weighted avg     0.7908    0.7620    0.7659     40428

# %% [markdown]
# ### Experiment 3

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(32, return_sequences=True)))
model.add(Attention())
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 64)          6188096
#
#  dropout_4 (Dropout)         (None, None, 64)          0
#
#  bidirectional_4 (Bidirectio  (None, None, 64)         24832
#  nal)
#
#  attention_1 (Attention)     (None, 128)               20480
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,233,537
# Trainable params: 6,233,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM32_attention", X_train, y_train, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.5128 - accuracy: 0.7461
# Epoch 1: val_loss improved from inf to 0.47891, saving model to /content/Models/BI_LSTM32_attention.h5
# 5054/5054 [==============================] - 162s 31ms/step - loss: 0.5128 - accuracy: 0.7461 - val_loss: 0.4789 - val_accuracy: 0.7633
# Epoch 2/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4533 - accuracy: 0.7801
# Epoch 2: val_loss improved from 0.47891 to 0.46736, saving model to /content/Models/BI_LSTM32_attention.h5
# 5054/5054 [==============================] - 155s 31ms/step - loss: 0.4533 - accuracy: 0.7801 - val_loss: 0.4674 - val_accuracy: 0.7750
# Epoch 3/10
# 5054/5054 [==============================] - ETA: 0s - loss: 0.4190 - accuracy: 0.7982
# Epoch 3: val_loss improved from 0.46736 to 0.46147, saving model to /content/Models/BI_LSTM32_attention.h5
# 5054/5054 [==============================] - 155s 31ms/step - loss: 0.4190 - accuracy: 0.7982 - val_loss: 0.4615 - val_accuracy: 0.7786
# Epoch 4/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3929 - accuracy: 0.8129
# Epoch 4: val_loss did not improve from 0.46147
# 5054/5054 [==============================] - 154s 31ms/step - loss: 0.3929 - accuracy: 0.8129 - val_loss: 0.4623 - val_accuracy: 0.7804
# Epoch 5/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3692 - accuracy: 0.8261
# Epoch 5: val_loss improved from 0.46147 to 0.45189, saving model to /content/Models/BI_LSTM32_attention.h5
# 5054/5054 [==============================] - 155s 31ms/step - loss: 0.3692 - accuracy: 0.8261 - val_loss: 0.4519 - val_accuracy: 0.7891
# Epoch 6/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3491 - accuracy: 0.8378
# Epoch 6: val_loss did not improve from 0.45189
# 5054/5054 [==============================] - 156s 31ms/step - loss: 0.3491 - accuracy: 0.8378 - val_loss: 0.4673 - val_accuracy: 0.7839
# Epoch 7/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3310 - accuracy: 0.8469
# Epoch 7: val_loss did not improve from 0.45189
# 5054/5054 [==============================] - 154s 31ms/step - loss: 0.3310 - accuracy: 0.8469 - val_loss: 0.4666 - val_accuracy: 0.7836
# Epoch 8/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3160 - accuracy: 0.8541
# Epoch 8: val_loss did not improve from 0.45189
# 5054/5054 [==============================] - 154s 30ms/step - loss: 0.3160 - accuracy: 0.8541 - val_loss: 0.4850 - val_accuracy: 0.7854
# Epoch 9/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.3031 - accuracy: 0.8616
# Epoch 9: val_loss did not improve from 0.45189
# 5054/5054 [==============================] - 154s 30ms/step - loss: 0.3031 - accuracy: 0.8616 - val_loss: 0.4724 - val_accuracy: 0.7879
# Epoch 10/10
# 5053/5054 [============================>.] - ETA: 0s - loss: 0.2922 - accuracy: 0.8671
# Epoch 10: val_loss did not improve from 0.45189
# 5054/5054 [==============================] - 154s 31ms/step - loss: 0.2922 - accuracy: 0.8671 - val_loss: 0.4687 - val_accuracy: 0.7931

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8327    0.8388    0.8358     25348
#            1     0.7257    0.7168    0.7212     15080
#
#     accuracy                         0.7933     40428
#    macro avg     0.7792    0.7778    0.7785     40428
# weighted avg     0.7928    0.7933    0.7930     40428

# %% [markdown]
# # Data Augmentation for class balancing
# It is possible to increase the number of elements of class 1, just swapping the two questions q1 and q2.

# %%
counts = train_questions['is_duplicate'].value_counts()
counts
# Out:
# 0    204207
# 1    119224
# Name: is_duplicate, dtype: int64

# %%
support_duplicate = counts[1]
support_no_duplicate = counts[0]
needed_to_balance = support_no_duplicate - support_duplicate

augmented_train_questions = train_questions
duplicate_train_questions = train_questions[train_questions['is_duplicate'] == 1]

# Take samples from the class 'is_duplicate' and add to augmented_train_questions
samples = duplicate_train_questions.sample(n=needed_to_balance, replace=False)
# We need to swap the two questions to get a new tokenizer
samples = samples.rename(columns={"qid1": "qid2", 
                        "qid2": "qid1", 
                        "question1": "question2", 
                        "question2": "question1", 
                        "question1_cleaned": "question2_cleaned", 
                        "question2_cleaned": "question1_cleaned",
                        "tokenizer_1": "tokenizer_2", 
                        "tokenizer_2": "tokenizer_1"})
samples['tokenizer'] = samples['tokenizer_1'] + samples['tokenizer_2']

augmented_train_questions = pd.concat([augmented_train_questions, samples], ignore_index=True)

# %%
augmented_train_questions['is_duplicate'].value_counts()
# Out:
# 0    204207
# 1    204207
# Name: is_duplicate, dtype: int64

# %%
y_train_augmented = augmented_train_questions[['is_duplicate']]
X_train_augmented = augmented_train_questions[['tokenizer']]
X_train_augmented = sequence.pad_sequences(X_train_augmented.tokenizer, maxlen = m_len, padding='post', truncating='post')

# %% [markdown]
# ## Experiment 1

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 64)          6188096
#
#  dropout_1 (Dropout)         (None, None, 64)          0
#
#  bidirectional_1 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,254,273
# Trainable params: 6,254,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_augmentation", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10, patience=3)
# Out:
# Epoch 1/10
# 6382/6382 [==============================] - ETA: 0s - loss: 0.5190 - accuracy: 0.7376
# Epoch 1: val_loss improved from inf to 0.48470, saving model to /content/Models/BI_LSTM64_augmentation.h5
# 6382/6382 [==============================] - 224s 34ms/step - loss: 0.5190 - accuracy: 0.7376 - val_loss: 0.4847 - val_accuracy: 0.7629
# Epoch 2/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4383 - accuracy: 0.7931
# Epoch 2: val_loss did not improve from 0.48470
# 6382/6382 [==============================] - 215s 34ms/step - loss: 0.4383 - accuracy: 0.7931 - val_loss: 0.4860 - val_accuracy: 0.7657
# Epoch 3/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3907 - accuracy: 0.8218
# Epoch 3: val_loss improved from 0.48470 to 0.46395, saving model to /content/Models/BI_LSTM64_augmentation.h5
# 6382/6382 [==============================] - 211s 33ms/step - loss: 0.3907 - accuracy: 0.8218 - val_loss: 0.4640 - val_accuracy: 0.7812
# Epoch 4/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3548 - accuracy: 0.8413
# Epoch 4: val_loss improved from 0.46395 to 0.46231, saving model to /content/Models/BI_LSTM64_augmentation.h5
# 6382/6382 [==============================] - 216s 34ms/step - loss: 0.3548 - accuracy: 0.8413 - val_loss: 0.4623 - val_accuracy: 0.7871
# Epoch 5/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3289 - accuracy: 0.8545
# Epoch 5: val_loss did not improve from 0.46231
# 6382/6382 [==============================] - 213s 33ms/step - loss: 0.3289 - accuracy: 0.8545 - val_loss: 0.4891 - val_accuracy: 0.7749
# Epoch 6/10
# 6382/6382 [==============================] - ETA: 0s - loss: 0.3074 - accuracy: 0.8657
# Epoch 6: val_loss did not improve from 0.46231
# 6382/6382 [==============================] - 215s 34ms/step - loss: 0.3074 - accuracy: 0.8657 - val_loss: 0.4649 - val_accuracy: 0.7970
# Epoch 7/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.2904 - accuracy: 0.8745
# Epoch 7: val_loss did not improve from 0.46231
# 6382/6382 [==============================] - 215s 34ms/step - loss: 0.2905 - accuracy: 0.8745 - val_loss: 0.4874 - val_accuracy: 0.7906

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8792    0.7709    0.8215     25348
#            1     0.6810    0.8220    0.7449     15080
#
#     accuracy                         0.7900     40428
#    macro avg     0.7801    0.7965    0.7832     40428
# weighted avg     0.8053    0.7900    0.7930     40428

# %% [markdown]
# ## Experiment 2

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
model.add(Attention())
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, None, 64)          6188096
#
#  dropout_3 (Dropout)         (None, None, 64)          0
#
#  bidirectional_3 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  attention (Attention)       (None, 128)               49152
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,303,425
# Trainable params: 6,303,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_attention_augmentation", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10)
# Out:
# Epoch 1/10
# 6382/6382 [==============================] - ETA: 0s - loss: 0.5234 - accuracy: 0.7322
# Epoch 1: val_loss improved from inf to 0.52023, saving model to /content/Models/BI_LSTM64_attention_augmentation.h5
# 6382/6382 [==============================] - 217s 33ms/step - loss: 0.5234 - accuracy: 0.7322 - val_loss: 0.5202 - val_accuracy: 0.7428
# Epoch 2/10
# 6382/6382 [==============================] - ETA: 0s - loss: 0.4497 - accuracy: 0.7837
# Epoch 2: val_loss improved from 0.52023 to 0.49132, saving model to /content/Models/BI_LSTM64_attention_augmentation.h5
# 6382/6382 [==============================] - 209s 33ms/step - loss: 0.4497 - accuracy: 0.7837 - val_loss: 0.4913 - val_accuracy: 0.7565
# Epoch 3/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4023 - accuracy: 0.8136
# Epoch 3: val_loss improved from 0.49132 to 0.48189, saving model to /content/Models/BI_LSTM64_attention_augmentation.h5
# 6382/6382 [==============================] - 210s 33ms/step - loss: 0.4023 - accuracy: 0.8136 - val_loss: 0.4819 - val_accuracy: 0.7636
# Epoch 4/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3661 - accuracy: 0.8347
# Epoch 4: val_loss did not improve from 0.48189
# 6382/6382 [==============================] - 215s 34ms/step - loss: 0.3661 - accuracy: 0.8346 - val_loss: 0.5158 - val_accuracy: 0.7490
# Epoch 5/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3384 - accuracy: 0.8502
# Epoch 5: val_loss did not improve from 0.48189
# 6382/6382 [==============================] - 212s 33ms/step - loss: 0.3384 - accuracy: 0.8502 - val_loss: 0.4949 - val_accuracy: 0.7682
# Epoch 6/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3164 - accuracy: 0.8608
# Epoch 6: val_loss did not improve from 0.48189
# 6382/6382 [==============================] - 213s 33ms/step - loss: 0.3164 - accuracy: 0.8608 - val_loss: 0.5030 - val_accuracy: 0.7800
# Epoch 7/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.2983 - accuracy: 0.8703
# Epoch 7: val_loss did not improve from 0.48189
# 6382/6382 [==============================] - 213s 33ms/step - loss: 0.2983 - accuracy: 0.8703 - val_loss: 0.4982 - val_accuracy: 0.7798
# Epoch 8/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.2836 - accuracy: 0.8776
# Epoch 8: val_loss did not improve from 0.48189
# 6382/6382 [==============================] - 208s 33ms/step - loss: 0.2836 - accuracy: 0.8776 - val_loss: 0.5074 - val_accuracy: 0.7842

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8692    0.7733    0.8185     25348
#            1     0.6786    0.8044    0.7362     15080
#
#     accuracy                         0.7849     40428
#    macro avg     0.7739    0.7889    0.7773     40428
# weighted avg     0.7981    0.7849    0.7878     40428

# %% [markdown]
# ## Experiment 3

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 32))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, None, 32)          3094048
#
#  dropout_2 (Dropout)         (None, None, 32)          0
#
#  bidirectional_2 (Bidirectio  (None, 128)              49664
#  nal)
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,143,841
# Trainable params: 3,143,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Embedding32_augmented", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10, patience=3)
# Out:
# Epoch 1/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.5302 - accuracy: 0.7308
# Epoch 1: val_loss improved from inf to 0.53253, saving model to /content/Models/BI_LSTM64_Embedding32_augmented.h5
# 6382/6382 [==============================] - 208s 31ms/step - loss: 0.5303 - accuracy: 0.7308 - val_loss: 0.5325 - val_accuracy: 0.7205
# Epoch 2/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4601 - accuracy: 0.7800
# Epoch 2: val_loss improved from 0.53253 to 0.47226, saving model to /content/Models/BI_LSTM64_Embedding32_augmented.h5
# 6382/6382 [==============================] - 198s 31ms/step - loss: 0.4601 - accuracy: 0.7800 - val_loss: 0.4723 - val_accuracy: 0.7663
# Epoch 3/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4222 - accuracy: 0.8027
# Epoch 3: val_loss did not improve from 0.47226
# 6382/6382 [==============================] - 196s 31ms/step - loss: 0.4222 - accuracy: 0.8027 - val_loss: 0.4884 - val_accuracy: 0.7596
# Epoch 4/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3923 - accuracy: 0.8196
# Epoch 4: val_loss did not improve from 0.47226
# 6382/6382 [==============================] - 200s 31ms/step - loss: 0.3923 - accuracy: 0.8196 - val_loss: 0.4776 - val_accuracy: 0.7710
# Epoch 5/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3710 - accuracy: 0.8319
# Epoch 5: val_loss did not improve from 0.47226
# 6382/6382 [==============================] - 198s 31ms/step - loss: 0.3710 - accuracy: 0.8319 - val_loss: 0.4832 - val_accuracy: 0.7708

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8671    0.7468    0.8025     25348
#            1     0.6549    0.8077    0.7233     15080
#
#     accuracy                         0.7695     40428
#    macro avg     0.7610    0.7772    0.7629     40428
# weighted avg     0.7880    0.7695    0.7729     40428

# %% [markdown]
# ## Experiment 4

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 32))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
model.add(Attention())
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, None, 32)          3094048
#
#  dropout_4 (Dropout)         (None, None, 32)          0
#
#  bidirectional_4 (Bidirectio  (None, None, 128)        49664
#  nal)
#
#  attention_1 (Attention)     (None, 128)               49152
#
#  dense_4 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,192,993
# Trainable params: 3,192,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_Embedding32__attention_augmented", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10, patience=3)
# Out:
# Epoch 1/10
# 6382/6382 [==============================] - ETA: 0s - loss: 0.5298 - accuracy: 0.7280
# Epoch 1: val_loss improved from inf to 0.50832, saving model to /content/Models/BI_LSTM64_Embedding32__attention_augmented.h5
# 6382/6382 [==============================] - 220s 34ms/step - loss: 0.5298 - accuracy: 0.7280 - val_loss: 0.5083 - val_accuracy: 0.7443
# Epoch 2/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4682 - accuracy: 0.7706
# Epoch 2: val_loss improved from 0.50832 to 0.50573, saving model to /content/Models/BI_LSTM64_Embedding32__attention_augmented.h5
# 6382/6382 [==============================] - 210s 33ms/step - loss: 0.4682 - accuracy: 0.7706 - val_loss: 0.5057 - val_accuracy: 0.7398
# Epoch 3/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4348 - accuracy: 0.7926
# Epoch 3: val_loss improved from 0.50573 to 0.49754, saving model to /content/Models/BI_LSTM64_Embedding32__attention_augmented.h5
# 6382/6382 [==============================] - 211s 33ms/step - loss: 0.4348 - accuracy: 0.7926 - val_loss: 0.4975 - val_accuracy: 0.7504
# Epoch 4/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.4091 - accuracy: 0.8087
# Epoch 4: val_loss improved from 0.49754 to 0.49273, saving model to /content/Models/BI_LSTM64_Embedding32__attention_augmented.h5
# 6382/6382 [==============================] - 212s 33ms/step - loss: 0.4091 - accuracy: 0.8087 - val_loss: 0.4927 - val_accuracy: 0.7565
# Epoch 5/10
# 6382/6382 [==============================] - ETA: 0s - loss: 0.3875 - accuracy: 0.8213
# Epoch 5: val_loss improved from 0.49273 to 0.48853, saving model to /content/Models/BI_LSTM64_Embedding32__attention_augmented.h5
# 6382/6382 [==============================] - 210s 33ms/step - loss: 0.3875 - accuracy: 0.8213 - val_loss: 0.4885 - val_accuracy: 0.7679
# Epoch 6/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3676 - accuracy: 0.8324
# Epoch 6: val_loss did not improve from 0.48853
# 6382/6382 [==============================] - 208s 33ms/step - loss: 0.3677 - accuracy: 0.8324 - val_loss: 0.5005 - val_accuracy: 0.7647
# Epoch 7/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3510 - accuracy: 0.8419
# Epoch 7: val_loss did not improve from 0.48853
# 6382/6382 [==============================] - 208s 33ms/step - loss: 0.3510 - accuracy: 0.8419 - val_loss: 0.4921 - val_accuracy: 0.7711
# Epoch 8/10
# 6381/6382 [============================>.] - ETA: 0s - loss: 0.3366 - accuracy: 0.8493
# Epoch 8: val_loss did not improve from 0.48853
# 6382/6382 [==============================] - 207s 32ms/step - loss: 0.3366 - accuracy: 0.8493 - val_loss: 0.5366 - val_accuracy: 0.7584

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8871    0.7040    0.7850     25348
#            1     0.6306    0.8495    0.7239     15080
#
#     accuracy                         0.7583     40428
#    macro avg     0.7589    0.7767    0.7545     40428
# weighted avg     0.7915    0.7583    0.7622     40428

# %% [markdown]
# # Total data augmentation

# %%
counts = train_questions['is_duplicate'].value_counts()
counts
# Out:
# 0    204207
# 1    119224
# Name: is_duplicate, dtype: int64

# %%
augmented_train_questions = train_questions

# We need to swap the two questions to get a new tokenizer
augmented_train_questions = augmented_train_questions.rename(columns={"qid1": "qid2", 
                        "qid2": "qid1", 
                        "question1": "question2", 
                        "question2": "question1", 
                        "question1_cleaned": "question2_cleaned", 
                        "question2_cleaned": "question1_cleaned",
                        "tokenizer_1": "tokenizer_2", 
                        "tokenizer_2": "tokenizer_1"})
augmented_train_questions['tokenizer'] = augmented_train_questions['tokenizer_1'] + augmented_train_questions['tokenizer_2']

augmented_train_questions = pd.concat([train_questions, augmented_train_questions], ignore_index=True)

# %%
augmented_train_questions['is_duplicate'].value_counts()
# Out:
# 0    408414
# 1    238448
# Name: is_duplicate, dtype: int64

# %%
y_train_augmented = augmented_train_questions[['is_duplicate']]
X_train_augmented = augmented_train_questions[['tokenizer']]
X_train_augmented = sequence.pad_sequences(X_train_augmented.tokenizer, maxlen = m_len, padding='post', truncating='post')

# %%
# class weight
class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train['is_duplicate'].tolist())

class_weights = dict(zip(np.unique(y_train), class_weights))
class_weights
# Out:
# {0: 0.7919194738672034, 1: 1.3564005569348454}

# %% [markdown]
# ## Experiment 1

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 64)          6188096
#
#  dropout_6 (Dropout)         (None, None, 64)          0
#
#  bidirectional_6 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_6 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,254,273
# Trainable params: 6,254,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_total_augmentation", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10, patience=3)
# Out:
# Epoch 1/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.4790 - accuracy: 0.7665
# Epoch 1: val_loss improved from inf to 0.45770, saving model to /content/Models/BI_LSTM64_total_augmentation.h5
# 10108/10108 [==============================] - 313s 31ms/step - loss: 0.4790 - accuracy: 0.7665 - val_loss: 0.4577 - val_accuracy: 0.7828
# Epoch 2/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.3943 - accuracy: 0.8162
# Epoch 2: val_loss improved from 0.45770 to 0.43906, saving model to /content/Models/BI_LSTM64_total_augmentation.h5
# 10108/10108 [==============================] - 300s 30ms/step - loss: 0.3943 - accuracy: 0.8162 - val_loss: 0.4391 - val_accuracy: 0.7961
# Epoch 3/10
# 10108/10108 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.8423
# Epoch 3: val_loss did not improve from 0.43906
# 10108/10108 [==============================] - 305s 30ms/step - loss: 0.3466 - accuracy: 0.8423 - val_loss: 0.4468 - val_accuracy: 0.8022
# Epoch 4/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.3133 - accuracy: 0.8594
# Epoch 4: val_loss did not improve from 0.43906
# 10108/10108 [==============================] - 303s 30ms/step - loss: 0.3133 - accuracy: 0.8594 - val_loss: 0.4530 - val_accuracy: 0.8006
# Epoch 5/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.2881 - accuracy: 0.8720
# Epoch 5: val_loss did not improve from 0.43906
# 10108/10108 [==============================] - 301s 30ms/step - loss: 0.2881 - accuracy: 0.8720 - val_loss: 0.4495 - val_accuracy: 0.8068

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8508    0.8342    0.8424     25348
#            1     0.7302    0.7541    0.7420     15080
#
#     accuracy                         0.8043     40428
#    macro avg     0.7905    0.7942    0.7922     40428
# weighted avg     0.8058    0.8043    0.8050     40428

# %% [markdown]
# ## Experiment 2

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64, return_sequences=True)))
model.add(Attention())
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, None, 64)          6188096
#
#  dropout_7 (Dropout)         (None, None, 64)          0
#
#  bidirectional_7 (Bidirectio  (None, None, 128)        66048
#  nal)
#
#  attention_1 (Attention)     (None, 128)               49152
#
#  dense_7 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,303,425
# Trainable params: 6,303,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_attention_total_augmentation", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10, patience=3)
# Out:
# Epoch 1/10
# 10108/10108 [==============================] - ETA: 0s - loss: 0.4804 - accuracy: 0.7644
# Epoch 1: val_loss improved from inf to 0.46775, saving model to /content/Models/BI_LSTM64_attention_total_augmentation.h5
# 10108/10108 [==============================] - 329s 32ms/step - loss: 0.4804 - accuracy: 0.7644 - val_loss: 0.4678 - val_accuracy: 0.7750
# Epoch 2/10
# 10108/10108 [==============================] - ETA: 0s - loss: 0.4038 - accuracy: 0.8083
# Epoch 2: val_loss improved from 0.46775 to 0.45277, saving model to /content/Models/BI_LSTM64_attention_total_augmentation.h5
# 10108/10108 [==============================] - 322s 32ms/step - loss: 0.4038 - accuracy: 0.8083 - val_loss: 0.4528 - val_accuracy: 0.7870
# Epoch 3/10
# 10108/10108 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8346
# Epoch 3: val_loss did not improve from 0.45277
# 10108/10108 [==============================] - 322s 32ms/step - loss: 0.3575 - accuracy: 0.8346 - val_loss: 0.4681 - val_accuracy: 0.7930
# Epoch 4/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.3224 - accuracy: 0.8530
# Epoch 4: val_loss did not improve from 0.45277
# 10108/10108 [==============================] - 319s 32ms/step - loss: 0.3224 - accuracy: 0.8530 - val_loss: 0.4607 - val_accuracy: 0.7918
# Epoch 5/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.2956 - accuracy: 0.8670
# Epoch 5: val_loss did not improve from 0.45277
# 10108/10108 [==============================] - 322s 32ms/step - loss: 0.2956 - accuracy: 0.8670 - val_loss: 0.4768 - val_accuracy: 0.7949

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8468    0.8201    0.8332     25348
#            1     0.7128    0.7505    0.7312     15080
#
#     accuracy                         0.7942     40428
#    macro avg     0.7798    0.7853    0.7822     40428
# weighted avg     0.7968    0.7942    0.7952     40428

# %% [markdown]
# ## Experiment 3

# %%
model = Sequential()
model.add(Embedding(num_distinct_words, 64))
model.add(Dropout(0.5))
model.add(layers.Bidirectional(layers.LSTM(64)))
model.add(Dense(1, activation = 'sigmoid'))

compile_model(model)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, None, 64)          6188096
#
#  dropout_8 (Dropout)         (None, None, 64)          0
#
#  bidirectional_8 (Bidirectio  (None, 128)              66048
#  nal)
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,254,273
# Trainable params: 6,254,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
run_model(model, "BI_LSTM64_weights_total_augmentation", X_train_augmented, y_train_augmented, X_validation, y_validation, epochs=10, class_weight=class_weights)
# Out:
# Epoch 1/10
# 10108/10108 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.7471
# Epoch 1: val_loss improved from inf to 0.47273, saving model to /content/Models/BI_LSTM64_weights_total_augmentation.h5
# 10108/10108 [==============================] - 308s 30ms/step - loss: 0.5043 - accuracy: 0.7471 - val_loss: 0.4727 - val_accuracy: 0.7710
# Epoch 2/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.4132 - accuracy: 0.8030
# Epoch 2: val_loss improved from 0.47273 to 0.46237, saving model to /content/Models/BI_LSTM64_weights_total_augmentation.h5
# 10108/10108 [==============================] - 302s 30ms/step - loss: 0.4132 - accuracy: 0.8031 - val_loss: 0.4624 - val_accuracy: 0.7784
# Epoch 3/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.3623 - accuracy: 0.8317
# Epoch 3: val_loss did not improve from 0.46237
# 10108/10108 [==============================] - 303s 30ms/step - loss: 0.3623 - accuracy: 0.8317 - val_loss: 0.4904 - val_accuracy: 0.7755
# Epoch 4/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.3272 - accuracy: 0.8502
# Epoch 4: val_loss did not improve from 0.46237
# 10108/10108 [==============================] - 299s 30ms/step - loss: 0.3272 - accuracy: 0.8502 - val_loss: 0.4677 - val_accuracy: 0.7905
# Epoch 5/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.3009 - accuracy: 0.8630
# Epoch 5: val_loss did not improve from 0.46237
# 10108/10108 [==============================] - 298s 29ms/step - loss: 0.3009 - accuracy: 0.8630 - val_loss: 0.5127 - val_accuracy: 0.7706
# Epoch 6/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.2801 - accuracy: 0.8727
# Epoch 6: val_loss did not improve from 0.46237
# 10108/10108 [==============================] - 300s 30ms/step - loss: 0.2801 - accuracy: 0.8727 - val_loss: 0.4973 - val_accuracy: 0.7888
# Epoch 7/10
# 10107/10108 [============================>.] - ETA: 0s - loss: 0.2643 - accuracy: 0.8811
# Epoch 7: val_loss did not improve from 0.46237
# 10108/10108 [==============================] - 308s 30ms/step - loss: 0.2643 - accuracy: 0.8811 - val_loss: 0.5043 - val_accuracy: 0.7918

# %%
evaluate_model(model, X_test, y_test)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.8780    0.7741    0.8228     25348
#            1     0.6832    0.8192    0.7451     15080
#
#     accuracy                         0.7909     40428
#    macro avg     0.7806    0.7966    0.7839     40428
# weighted avg     0.8053    0.7909    0.7938     40428
